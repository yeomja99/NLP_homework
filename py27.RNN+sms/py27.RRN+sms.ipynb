# %%
# !pip install torchtext==0.4.0
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Requirement already satisfied: torchtext==0.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages (0.4.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages (from torchtext==0.4.0) (2.22.0)
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages (from torchtext==0.4.0) (1.4.0)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages (from torchtext==0.4.0) (1.16.5)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages (from torchtext==0.4.0) (1.12.0)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages (from torchtext==0.4.0) (4.36.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages (from requests->torchtext==0.4.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages (from requests->torchtext==0.4.0) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages (from requests->torchtext==0.4.0) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages (from requests->torchtext==0.4.0) (2019.11.28)
# WARNING: You are using pip version 19.2.3, however version 20.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
max_length = 256 # sms(가사) 최대 길이

# %% [markdown]
# # 1. 데이터 불러오기

# %%
import pandas as pd

# %%
df = pd.read_csv('sms.tsv', sep='\t')
print(df.columns)
print(df.shape)
# Out:
# Index([u'label', u'sms'], dtype='object')
# (5572, 2)

# %%
df.head()
# Out:
#   label                                                sms
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# 클래스 파악
classes = sorted(set(set(df['label'])))
class_to_idx = {}

for i, c in enumerate(classes): # 모든 클래스에 대해
    class_to_idx.update({c:i})
    
nclass = len(classes)

print("# of classes: %d" %nclass)
print(classes)
print(class_to_idx)
# Out:
# # of classes: 2
# ['ham', 'spam']
# {'ham': 0, 'spam': 1}

# %% [markdown]
# # 2. 새로운 DataFrame

# %% [markdown]
# ## 1) 'labels, sms'만 남기기

# %% [markdown]
# ## 2) 최대 텍스트 길이만큼 자르기 # pandas.Series.str.slice

# %% [markdown]
# - '성별, 가사'만 남기려면?

# %%
new_df = pd.DataFrame({'label':df['label'], 'sms':df['sms'].str.slice(start = 0, stop=max_length)})

# %% [markdown]
# ## 3) 중복 제거

# %%
len(new_df)
# Out:
# 5572

# %%
new_df = pd.DataFrame(new_df.drop_duplicates())

# %%
len(new_df)
# Out:
# 5169

# %% [markdown]
#  ## 4) 셔플

# %%
df_shuffled = new_df.sample(frac=1).reset_index(drop=True)
df_shuffled.head()
# Out:
#   label                                                sms
# 0   ham  Fuck cedar key and fuck her (come over anyway ...
# 1   ham  The world's most happiest frnds never have the...
# 2   ham  Got ur mail Dileep.thank you so muchand look f...
# 3  spam  Reply to win £100 weekly! What professional sp...
# 4  spam  New Tones This week include: 1)McFly-All Ab..,...

# %% [markdown]
# ## 5) train, test 나누기

# %%
# train: test = 9:1
# train: test = 540:60 -> train:valid:test = 432:108:60
train_ratio = 0.9

# train dataset
s, e =0, int(df_shuffled.shape[0] * train_ratio) # of rows
df_train = pd.DataFrame({'label':df_shuffled['label'][s:e],
                        'sms':df_shuffled['sms'][s:e]})
print("index for test: %d~%d" %(s,e))

# test dataset
s, e = e, e+int(df_shuffled.shape[0] * (1.0 - train_ratio))
print("index for test: %d~%d" %(s,e))
df_test = pd.DataFrame({'label':df_shuffled['label'][s:e], 'sms': df_shuffled['sms'][s:e]})
# Out:
# index for test: 0~4652
# index for test: 4652~5168

# %%
# column 수 확인
print(df_train.shape)
print(df_test.shape)
# Out:
# (4652, 2)
# (516, 2)

# %% [markdown]
# ## 4) 저장

# %%
df_train.to_csv('./sms.maxlen.uniq.shuf.train.tsv', header = False, index = False, sep = '\t')
df_test.to_csv('./sms.maxlen.uniq.shuf.test.tsv', header = False, index = False, sep = '\t')

# %%
import torch
print(torch.__version__)
# Out:
# 1.4.0

# %% [markdown]
# # 데이터 로드하기

# %%
import torchtext
import numpy as np

# %%
from data_loader import DataLoader

# %% [markdown]
# # RNN+SMS 구현

# %% [markdown]
# ## 0.1 라이브러리 임포트

# %%
import torch
import torch.nn as nn
import torchvision.datasets as dset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.autograd import Variable
import numpy as np

# %% [markdown]
# ## 0.2 하이퍼파라미터 셋팅

# %%
# Hyper-parameters
batch_size = 128
num_epochs = 10

word_vec_size = 256
dropout_p = 0.3

hidden_size = 512
num_layers = 4

# yhk 추가
learning_rate = 0.001 # 디폴트 0,001

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## 1. SMS train, test dataset 가져오기

# %%
from data_loader import DataLoader

# %%
loaders = DataLoader(
    train_fn='./sms.maxlen.uniq.shuf.train.tsv',
    batch_size=batch_size,
    valid_ratio=.2,
    device=-1,
    max_vocab=999999,
    min_freq=5,
)

# %%
test_loaders = DataLoader(
    train_fn='./sms.maxlen.uniq.shuf.train.tsv',
    batch_size=batch_size,
    valid_ratio=.01,  # 모두 train
    device=-1,
    max_vocab=999999,
    min_freq=5,
)

# %% [markdown]
# ## 2. 대략적인 데이터 형태

# %%
print("|train| =", len(loaders.train_loader.dataset),
     '|valid| = ', len(loaders.valid_loader.dataset))

vocab_size = len(loaders.text.vocab)
num_classes = len(loaders.label.vocab)
print("|vocab| =", vocab_size, "|classes| =", num_classes)
# Out:
# ('|train| =', 3722, '|valid| = ', 930)
# ('|vocab| =', 1551, '|classes| =', 2)

# %% [markdown]
# ## 3. 데이터 로드함수
# 학습시킬 때 batch_size 단위로 끊어서 로드하기 위함

# %% [markdown]
# ### 데이터 로드함수 이해하기

# %%
n = 3 # 샘플로 출력할 데이터 개수
for i, data in enumerate(loaders.train_loader):
    labels = data.label
    texts = data.text
    
    if i>n:
        break
    print("[%d]" %i)
    print("한 번에 로드되는 데이터 크기:", len(labels))
    
    # 출력
    for j in range(n):
        label = labels[j].numpy()
        text = texts[j].numpy()
        print("label: ", label)
        print("text: ", text.shape)
# Out:
# [0]
# ('\xed\x95\x9c \xeb\xb2\x88\xec\x97\x90 \xeb\xa1\x9c\xeb\x93\x9c\xeb\x90\x98\xeb\x8a\x94 \xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0 \xed\x81\xac\xea\xb8\xb0:', 128)
# ('label: ', array(0))
# ('text: ', (55,))
# ('label: ', array(0))
# ('text: ', (55,))
# ('label: ', array(0))
# ('text: ', (55,))
# [1]
# ('\xed\x95\x9c \xeb\xb2\x88\xec\x97\x90 \xeb\xa1\x9c\xeb\x93\x9c\xeb\x90\x98\xeb\x8a\x94 \xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0 \xed\x81\xac\xea\xb8\xb0:', 128)
# ('label: ', array(0))
# ('text: ', (8,))
# ('label: ', array(0))
# ('text: ', (8,))
# ('label: ', array(0))
# ('text: ', (8,))
# [2]
# ('\xed\x95\x9c \xeb\xb2\x88\xec\x97\x90 \xeb\xa1\x9c\xeb\x93\x9c\xeb\x90\x98\xeb\x8a\x94 \xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0 \xed\x81\xac\xea\xb8\xb0:', 128)
# ('label: ', array(1))
# ('text: ', (11,))
# ('label: ', array(0))
# ('text: ', (11,))
# ('label: ', array(0))
# ('text: ', (11,))
# [3]
# ('\xed\x95\x9c \xeb\xb2\x88\xec\x97\x90 \xeb\xa1\x9c\xeb\x93\x9c\xeb\x90\x98\xeb\x8a\x94 \xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0 \xed\x81\xac\xea\xb8\xb0:', 128)
# ('label: ', array(0))
# ('text: ', (24,))
# ('label: ', array(0))
# ('text: ', (24,))
# ('label: ', array(1))
# ('text: ', (24,))

# %% [markdown]
# ## 4. 모델 선언

# %%
# Recurrent neural network(many-to-one)

class RNN(nn.Module):
    def __init__(self,
                input_size,
                word_vec_size,
                hidden_size,
                n_classes,
                num_layers=4,
                dropout_p=0.3
                ):
        super(RNN, self).__init__()
        
        self.input_size = input_size
        self.word_vec_size = word_vec_size
        self.hidden_size = hidden_size
        self.n_classes = n_classes
        self.num_layers = num_layers
        self.dropout_p = dropout_p
        
        # 입력 차원(vocab_size), 출력 차원(word_vec_size)
        self.emb = nn.Embedding(input_size, word_vec_size) # 부터
        
        self.lstm = nn.LSTM(input_size = word_vec_size,
                           hidden_size = hidden_size,
                           num_layers = num_layers,
                           dropout = dropout_p,
                           batch_first = True,
                           bidirectional=True)
        self.fc = nn.Linear(hidden_size*2, num_classes)
        self.activation = nn.LogSoftmax(dim=-1)
        
    def forward(self, x):
        # x: (batch_size, length)
        x = self.emb(x)

        # x: (batch_size, length, word_vec_size
        x, _ = self.lstm(x)

        # x: (Batch_size, length, hidden_size, 2)
        # x[:,-1]: (batch_size, 1, hidden_size*2)
        out = self.activation(self.fc(x[:,-1]))
        # self.fc(x[:,-1])

        return out

# %%
model = RNN( input_size = vocab_size,
                word_vec_size=word_vec_size,
                hidden_size=hidden_size,
                n_classes=num_classes,
                num_layers=num_layers,
                dropout_p=dropout_p)

# %%
def ComputeAccr(dloader, imodel):
    correct = 0
    total = 0

    model.eval()  # test mode
    for i, data in enumerate(dloader):   # batch_size 만큼
        texts = data.text.to(device)  # (batch_size, length)
        labels = data.label.to(device)  # (batch_size, num_classes)

        # Forward prop.
        output = model(texts)  # (batch_size, num_classes)
        _, output_index = torch.max(output, 1)  # (batch_size, 1)

        total += labels.size(0)
        correct += (output_index == labels).sum().float()
    #print("Accuracy of Test Data: {}".format(100*correct/total))

    model.train()
    return (100*correct/total).numpy()  # tensor -> numpy

# %%
print("Accracy of Test Data: %.2f" %ComputeAccr(loaders.valid_loader, model))
# Out:
# Accracy of Test Data: 13.66

# %% [markdown]
# ## 5. loss, optimizer

# %%
# Loss and optimizer
# loss_func = nn.CrossEntropyLoss()
loss_func = nn.NLLLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %% [markdown]
# ## 6. 학습

# %%
# Train the model
total_step = len(loaders.train_loader)
for epoch in range(num_epochs):
    for i, data in enumerate(loaders.train_loader):
        # x: (batch_size, 1, seq_length, input_size)) -> (batch_size, seq_length, input_size)
        #img = imgs          
        #img = img.reshape(-1, sequence_length, input_size).to(device)        
        # y: (batch_size, num_classes)
        #label = labels.to(device)  # y  # Variable(labels)
        
        texts = data.text.to(device)  # (batch_size, length)
        labels = data.label.to(device)  # (batch_size, num_classes)
        
        print("[%d]" %i)
        print(texts.shape)
        print(labels.shape)
        
        # Forward prop.
        outputs = model(texts)
        loss = loss_func(outputs, labels)
        
        # Backward prop. & optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        
#         if (i+1) % 2 == 0:          
#             print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
#                    .format(epoch+1, num_epochs, i+1, total_step, 
#                            loss.item()))    
            
        if (i+1) % 10 == 0:          
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accr: {:.2f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, 
                           loss.item(), 
                           ComputeAccr(loaders.valid_loader, model)))
# Out:
# [0]
# torch.Size([128, 9])
# torch.Size([128])
# [1]
# torch.Size([10, 60])
# torch.Size([10])
# [2]
# torch.Size([128, 6])
# torch.Size([128])
# [3]
# torch.Size([128, 25])
# torch.Size([128])
# [4]
# torch.Size([128, 14])
# torch.Size([128])
# [5]
# torch.Size([128, 12])
# torch.Size([128])
# [6]
# torch.Size([128, 5])
# torch.Size([128])
# [7]
# torch.Size([128, 7])
# torch.Size([128])
# [8]
# torch.Size([128, 16])
# torch.Size([128])
# [9]
# torch.Size([128, 55])
# torch.Size([128])
# Epoch [1/10], Step [10/30], Loss: 0.1272, Accr: 86.34
# [10]
# torch.Size([128, 7])
# torch.Size([128])
# [11]
# torch.Size([128, 28])
# torch.Size([128])
# [12]
# torch.Size([128, 8])
# torch.Size([128])
# [13]
# torch.Size([128, 8])
# torch.Size([128])
# [14]
# torch.Size([128, 4])
# torch.Size([128])
# [15]
# torch.Size([128, 5])
# torch.Size([128])
# [16]
# torch.Size([128, 15])
# torch.Size([128])
# [17]
# torch.Size([128, 11])
# torch.Size([128])
# [18]
# torch.Size([128, 12])
# torch.Size([128])
# [19]
# torch.Size([128, 19])
# torch.Size([128])
# Epoch [1/10], Step [20/30], Loss: 0.3930, Accr: 86.34
# [20]
# torch.Size([128, 10])
# torch.Size([128])
# [21]
# torch.Size([128, 34])
# torch.Size([128])
# [22]
# torch.Size([128, 27])
# torch.Size([128])
# [23]
# torch.Size([128, 6])
# torch.Size([128])
# [24]
# torch.Size([128, 18])
# torch.Size([128])
# [25]
# torch.Size([128, 22])
# torch.Size([128])
# [26]
# torch.Size([128, 9])
# torch.Size([128])
# [27]
# torch.Size([128, 31])
# torch.Size([128])
# [28]
# torch.Size([128, 24])
# torch.Size([128])
# [29]
# torch.Size([128, 21])
# torch.Size([128])
# Epoch [1/10], Step [30/30], Loss: 0.5035, Accr: 86.34
# [0]
# torch.Size([128, 9])
# torch.Size([128])
# [1]
# torch.Size([10, 60])
# torch.Size([10])
# [2]
# torch.Size([128, 16])
# torch.Size([128])
# [3]
# torch.Size([128, 6])
# torch.Size([128])
# [4]
# torch.Size([128, 11])
# torch.Size([128])
# [5]
# torch.Size([128, 25])
# torch.Size([128])
# [6]
# torch.Size([128, 31])
# torch.Size([128])
# [7]
# torch.Size([128, 12])
# torch.Size([128])
# [8]
# torch.Size([128, 18])
# torch.Size([128])
# [9]
# torch.Size([128, 7])
# torch.Size([128])
# Epoch [2/10], Step [10/30], Loss: 0.2202, Accr: 86.34
# [10]
# torch.Size([128, 22])
# torch.Size([128])
# [11]
# torch.Size([128, 12])
# torch.Size([128])
# [12]
# torch.Size([128, 8])
# torch.Size([128])
# [13]
# torch.Size([128, 4])
# torch.Size([128])
# [14]
# torch.Size([128, 55])
# torch.Size([128])
# [15]
# torch.Size([128, 6])
# torch.Size([128])
# [16]
# torch.Size([128, 8])
# torch.Size([128])
# [17]
# torch.Size([128, 15])
# torch.Size([128])
# [18]
# torch.Size([128, 5])
# torch.Size([128])
# [19]
# torch.Size([128, 14])
# torch.Size([128])
# Epoch [2/10], Step [20/30], Loss: 0.2541, Accr: 86.34
# [20]
# torch.Size([128, 7])
# torch.Size([128])
# [21]
# torch.Size([128, 19])
# torch.Size([128])
# [22]
# torch.Size([128, 5])
# torch.Size([128])
# [23]
# torch.Size([128, 34])
# torch.Size([128])
# [24]
# torch.Size([128, 28])
# torch.Size([128])
# [25]
# torch.Size([128, 27])
# torch.Size([128])
# [26]
# torch.Size([128, 24])
# torch.Size([128])
# [27]
# torch.Size([128, 21])
# torch.Size([128])
# [28]
# torch.Size([128, 10])
# torch.Size([128])
# [29]
# torch.Size([128, 9])
# torch.Size([128])
# Epoch [2/10], Step [30/30], Loss: 0.1363, Accr: 86.34
# [0]
# torch.Size([128, 25])
# torch.Size([128])
# [1]
# torch.Size([128, 10])
# torch.Size([128])
# [2]
# torch.Size([128, 12])
# torch.Size([128])
# [3]
# torch.Size([128, 9])
# torch.Size([128])
# [4]
# torch.Size([128, 24])
# torch.Size([128])
# [5]
# torch.Size([128, 18])
# torch.Size([128])
# [6]
# torch.Size([128, 5])
# torch.Size([128])
# [7]
# torch.Size([128, 6])
# torch.Size([128])
# [8]
# torch.Size([128, 21])
# torch.Size([128])
# [9]
# torch.Size([128, 11])
# torch.Size([128])
# Epoch [3/10], Step [10/30], Loss: 0.2529, Accr: 86.34
# [10]
# torch.Size([128, 7])
# torch.Size([128])
# [11]
# torch.Size([128, 55])
# torch.Size([128])
# [12]
# torch.Size([128, 9])
# torch.Size([128])
# [13]
# torch.Size([128, 28])
# torch.Size([128])
# [14]
# torch.Size([128, 6])
# torch.Size([128])
# [15]
# torch.Size([128, 4])
# torch.Size([128])
# [16]
# torch.Size([128, 31])
# torch.Size([128])
# [17]
# torch.Size([128, 8])
# torch.Size([128])
# [18]
# torch.Size([128, 14])
# torch.Size([128])
# [19]
# torch.Size([128, 8])
# torch.Size([128])
# Epoch [3/10], Step [20/30], Loss: 0.1411, Accr: 86.34
# [20]
# torch.Size([128, 7])
# torch.Size([128])
# [21]
# torch.Size([10, 60])
# torch.Size([10])
# [22]
# torch.Size([128, 16])
# torch.Size([128])
# [23]
# torch.Size([128, 34])
# torch.Size([128])
# [24]
# torch.Size([128, 12])
# torch.Size([128])
# [25]
# torch.Size([128, 5])
# torch.Size([128])
# [26]
# torch.Size([128, 19])
# torch.Size([128])
# [27]
# torch.Size([128, 15])
# torch.Size([128])
# [28]
# torch.Size([128, 22])
# torch.Size([128])
# [29]
# torch.Size([128, 27])
# torch.Size([128])
# Epoch [3/10], Step [30/30], Loss: 0.2771, Accr: 89.14
# [0]
# torch.Size([128, 5])
# torch.Size([128])
# [1]
# torch.Size([128, 55])
# torch.Size([128])
# [2]
# torch.Size([128, 21])
# torch.Size([128])
# [3]
# torch.Size([128, 6])
# torch.Size([128])
# [4]
# torch.Size([128, 18])
# torch.Size([128])
# [5]
# torch.Size([128, 10])
# torch.Size([128])
# [6]
# torch.Size([128, 4])
# torch.Size([128])
# [7]
# torch.Size([128, 34])
# torch.Size([128])
# [8]
# torch.Size([128, 27])
# torch.Size([128])
# [9]
# torch.Size([128, 12])
# torch.Size([128])
# Epoch [4/10], Step [10/30], Loss: 0.1058, Accr: 88.28
# [10]
# torch.Size([128, 5])
# torch.Size([128])
# [11]
# torch.Size([128, 19])
# torch.Size([128])
# [12]
# torch.Size([128, 6])
# torch.Size([128])
# [13]
# torch.Size([128, 31])
# torch.Size([128])
# [14]
# torch.Size([10, 60])
# torch.Size([10])
# [15]
# torch.Size([128, 22])
# torch.Size([128])
# [16]
# torch.Size([128, 15])
# torch.Size([128])
# [17]
# torch.Size([128, 28])
# torch.Size([128])
# [18]
# torch.Size([128, 16])
# torch.Size([128])
# [19]
# torch.Size([128, 7])
# torch.Size([128])
# Epoch [4/10], Step [20/30], Loss: 0.0562, Accr: 93.98
# [20]
# torch.Size([128, 8])
# torch.Size([128])
# [21]
# torch.Size([128, 14])
# torch.Size([128])
# [22]
# torch.Size([128, 7])
# torch.Size([128])
# [23]
# torch.Size([128, 8])
# torch.Size([128])
# [24]
# torch.Size([128, 9])
# torch.Size([128])
# [25]
# torch.Size([128, 11])
# torch.Size([128])
# [26]
# torch.Size([128, 9])
# torch.Size([128])
# [27]
# torch.Size([128, 24])
# torch.Size([128])
# [28]
# torch.Size([128, 25])
# torch.Size([128])
# [29]
# torch.Size([128, 12])
# torch.Size([128])
# Epoch [4/10], Step [30/30], Loss: 0.1671, Accr: 95.59
# [0]
# torch.Size([128, 5])
# torch.Size([128])
# [1]
# torch.Size([128, 16])
# torch.Size([128])
# [2]
# torch.Size([128, 9])
# torch.Size([128])
# [3]
# torch.Size([128, 34])
# torch.Size([128])
# [4]
# torch.Size([128, 25])
# torch.Size([128])
# [5]
# torch.Size([128, 7])
# torch.Size([128])
# [6]
# torch.Size([128, 10])
# torch.Size([128])
# [7]
# torch.Size([128, 18])
# torch.Size([128])
# [8]
# torch.Size([128, 15])
# torch.Size([128])
# [9]
# torch.Size([10, 60])
# torch.Size([10])
# Epoch [5/10], Step [10/30], Loss: 0.0078, Accr: 96.45
# [10]
# torch.Size([128, 19])
# torch.Size([128])
# [11]
# torch.Size([128, 22])
# torch.Size([128])
# [12]
# torch.Size([128, 21])
# torch.Size([128])
# [13]
# torch.Size([128, 12])
# torch.Size([128])
# [14]
# torch.Size([128, 14])
# torch.Size([128])
# [15]
# torch.Size([128, 6])
# torch.Size([128])
# [16]
# torch.Size([128, 28])
# torch.Size([128])
# [17]
# torch.Size([128, 4])
# torch.Size([128])
# [18]
# torch.Size([128, 7])
# torch.Size([128])
# [19]
# torch.Size([128, 31])
# torch.Size([128])
# Epoch [5/10], Step [20/30], Loss: 0.2868, Accr: 92.15
# [20]
# torch.Size([128, 24])
# torch.Size([128])
# [21]
# torch.Size([128, 8])
# torch.Size([128])
# [22]
# torch.Size([128, 9])
# torch.Size([128])
# [23]
# torch.Size([128, 12])
# torch.Size([128])
# [24]
# torch.Size([128, 8])
# torch.Size([128])
# [25]
# torch.Size([128, 5])
# torch.Size([128])
# [26]
# torch.Size([128, 6])
# torch.Size([128])
# [27]
# torch.Size([128, 27])
# torch.Size([128])
# [28]
# torch.Size([128, 11])
# torch.Size([128])
# [29]
# torch.Size([128, 55])
# torch.Size([128])
# Epoch [5/10], Step [30/30], Loss: 0.0477, Accr: 95.59
# [0]
# torch.Size([10, 60])
# torch.Size([10])
# [1]
# torch.Size([128, 34])
# torch.Size([128])
# [2]
# torch.Size([128, 4])
# torch.Size([128])
# [3]
# torch.Size([128, 55])
# torch.Size([128])
# [4]
# torch.Size([128, 15])
# torch.Size([128])
# [5]
# torch.Size([128, 22])
# torch.Size([128])
# [6]
# torch.Size([128, 12])
# torch.Size([128])
# [7]
# torch.Size([128, 19])
# torch.Size([128])
# [8]
# torch.Size([128, 5])
# torch.Size([128])
# [9]
# torch.Size([128, 31])
# torch.Size([128])
# Epoch [6/10], Step [10/30], Loss: 0.2615, Accr: 97.10
# [10]
# torch.Size([128, 11])
# torch.Size([128])
# [11]
# torch.Size([128, 6])
# torch.Size([128])
# [12]
# torch.Size([128, 24])
# torch.Size([128])
# [13]
# torch.Size([128, 9])
# torch.Size([128])
# [14]
# torch.Size([128, 9])
# torch.Size([128])
# [15]
# torch.Size([128, 27])
# torch.Size([128])
# [16]
# torch.Size([128, 16])
# torch.Size([128])
# [17]
# torch.Size([128, 25])
# torch.Size([128])
# [18]
# torch.Size([128, 8])
# torch.Size([128])
# [19]
# torch.Size([128, 6])
# torch.Size([128])
# Epoch [6/10], Step [20/30], Loss: 0.0108, Accr: 97.31
# [20]
# torch.Size([128, 8])
# torch.Size([128])
# [21]
# torch.Size([128, 5])
# torch.Size([128])
# [22]
# torch.Size([128, 28])
# torch.Size([128])
# [23]
# torch.Size([128, 14])
# torch.Size([128])
# [24]
# torch.Size([128, 12])
# torch.Size([128])
# [25]
# torch.Size([128, 21])
# torch.Size([128])
# [26]
# torch.Size([128, 7])
# torch.Size([128])
# [27]
# torch.Size([128, 10])
# torch.Size([128])
# [28]
# torch.Size([128, 18])
# torch.Size([128])
# [29]
# torch.Size([128, 7])
# torch.Size([128])
# Epoch [6/10], Step [30/30], Loss: 0.0452, Accr: 97.31
# [0]
# torch.Size([128, 31])
# torch.Size([128])
# [1]
# torch.Size([128, 25])
# torch.Size([128])
# [2]
# torch.Size([128, 16])
# torch.Size([128])
# [3]
# torch.Size([128, 6])
# torch.Size([128])
# [4]
# torch.Size([128, 4])
# torch.Size([128])
# [5]
# torch.Size([128, 55])
# torch.Size([128])
# [6]
# torch.Size([128, 24])
# torch.Size([128])
# [7]
# torch.Size([128, 19])
# torch.Size([128])
# [8]
# torch.Size([10, 60])
# torch.Size([10])
# [9]
# torch.Size([128, 5])
# torch.Size([128])
# Epoch [7/10], Step [10/30], Loss: 0.0081, Accr: 91.94
# [10]
# torch.Size([128, 21])
# torch.Size([128])
# [11]
# torch.Size([128, 14])
# torch.Size([128])
# [12]
# torch.Size([128, 6])
# torch.Size([128])
# [13]
# torch.Size([128, 34])
# torch.Size([128])
# [14]
# torch.Size([128, 7])
# torch.Size([128])
# [15]
# torch.Size([128, 12])
# torch.Size([128])
# [16]
# torch.Size([128, 8])
# torch.Size([128])
# [17]
# torch.Size([128, 18])
# torch.Size([128])
# [18]
# torch.Size([128, 15])
# torch.Size([128])
# [19]
# torch.Size([128, 8])
# torch.Size([128])
# Epoch [7/10], Step [20/30], Loss: 0.0262, Accr: 95.59
# [20]
# torch.Size([128, 9])
# torch.Size([128])
# [21]
# torch.Size([128, 5])
# torch.Size([128])
# [22]
# torch.Size([128, 22])
# torch.Size([128])
# [23]
# torch.Size([128, 27])
# torch.Size([128])
# [24]
# torch.Size([128, 10])
# torch.Size([128])
# [25]
# torch.Size([128, 11])
# torch.Size([128])
# [26]
# torch.Size([128, 12])
# torch.Size([128])
# [27]
# torch.Size([128, 9])
# torch.Size([128])
# [28]
# torch.Size([128, 7])
# torch.Size([128])
# [29]
# torch.Size([128, 28])
# torch.Size([128])
# Epoch [7/10], Step [30/30], Loss: 0.0524, Accr: 96.34
# [0]
# torch.Size([128, 8])
# torch.Size([128])
# [1]
# torch.Size([128, 14])
# torch.Size([128])
# [2]
# torch.Size([128, 12])
# torch.Size([128])
# [3]
# torch.Size([128, 31])
# torch.Size([128])
# [4]
# torch.Size([128, 19])
# torch.Size([128])
# [5]
# torch.Size([128, 11])
# torch.Size([128])
# [6]
# torch.Size([128, 24])
# torch.Size([128])
# [7]
# torch.Size([128, 15])
# torch.Size([128])
# [8]
# torch.Size([128, 55])
# torch.Size([128])
# [9]
# torch.Size([128, 7])
# torch.Size([128])
# Epoch [8/10], Step [10/30], Loss: 0.0208, Accr: 95.70
# [10]
# torch.Size([128, 8])
# torch.Size([128])
# [11]
# torch.Size([128, 6])
# torch.Size([128])
# [12]
# torch.Size([128, 16])
# torch.Size([128])
# [13]
# torch.Size([128, 5])
# torch.Size([128])
# [14]
# torch.Size([128, 18])
# torch.Size([128])
# [15]
# torch.Size([128, 34])
# torch.Size([128])
# [16]
# torch.Size([128, 22])
# torch.Size([128])
# [17]
# torch.Size([128, 5])
# torch.Size([128])
# [18]
# torch.Size([128, 25])
# torch.Size([128])
# [19]
# torch.Size([128, 28])
# torch.Size([128])
# Epoch [8/10], Step [20/30], Loss: 0.0615, Accr: 97.20
# [20]
# torch.Size([10, 60])
# torch.Size([10])
# [21]
# torch.Size([128, 12])
# torch.Size([128])
# [22]
# torch.Size([128, 9])
# torch.Size([128])
# [23]
# torch.Size([128, 9])
# torch.Size([128])
# [24]
# torch.Size([128, 10])
# torch.Size([128])
# [25]
# torch.Size([128, 21])
# torch.Size([128])
# [26]
# torch.Size([128, 7])
# torch.Size([128])
# [27]
# torch.Size([128, 4])
# torch.Size([128])
# [28]
# torch.Size([128, 6])
# torch.Size([128])
# [29]
# torch.Size([128, 27])
# torch.Size([128])
# Epoch [8/10], Step [30/30], Loss: 0.0871, Accr: 97.42
# [0]
# torch.Size([128, 24])
# torch.Size([128])
# [1]
# torch.Size([128, 6])
# torch.Size([128])
# [2]
# torch.Size([128, 8])
# torch.Size([128])
# [3]
# torch.Size([128, 10])
# torch.Size([128])
# [4]
# torch.Size([128, 27])
# torch.Size([128])
# [5]
# torch.Size([128, 12])
# torch.Size([128])
# [6]
# torch.Size([128, 14])
# torch.Size([128])
# [7]
# torch.Size([128, 28])
# torch.Size([128])
# [8]
# torch.Size([128, 31])
# torch.Size([128])
# [9]
# torch.Size([128, 25])
# torch.Size([128])
# Epoch [9/10], Step [10/30], Loss: 0.0586, Accr: 97.53
# [10]
# torch.Size([128, 9])
# torch.Size([128])
# [11]
# torch.Size([128, 7])
# torch.Size([128])
# [12]
# torch.Size([128, 7])
# torch.Size([128])
# [13]
# torch.Size([128, 11])
# torch.Size([128])
# [14]
# torch.Size([10, 60])
# torch.Size([10])
# [15]
# torch.Size([128, 21])
# torch.Size([128])
# [16]
# torch.Size([128, 6])
# torch.Size([128])
# [17]
# torch.Size([128, 5])
# torch.Size([128])
# [18]
# torch.Size([128, 16])
# torch.Size([128])
# [19]
# torch.Size([128, 9])
# torch.Size([128])
# Epoch [9/10], Step [20/30], Loss: 0.0234, Accr: 98.17
# [20]
# torch.Size([128, 34])
# torch.Size([128])
# [21]
# torch.Size([128, 8])
# torch.Size([128])
# [22]
# torch.Size([128, 12])
# torch.Size([128])
# [23]
# torch.Size([128, 18])
# torch.Size([128])
# [24]
# torch.Size([128, 4])
# torch.Size([128])
# [25]
# torch.Size([128, 22])
# torch.Size([128])
# [26]
# torch.Size([128, 55])
# torch.Size([128])
# [27]
# torch.Size([128, 5])
# torch.Size([128])
# [28]
# torch.Size([128, 19])
# torch.Size([128])
# [29]
# torch.Size([128, 15])
# torch.Size([128])
# Epoch [9/10], Step [30/30], Loss: 0.1069, Accr: 96.88
# [0]
# torch.Size([128, 14])
# torch.Size([128])
# [1]
# torch.Size([128, 6])
# torch.Size([128])
# [2]
# torch.Size([128, 25])
# torch.Size([128])
# [3]
# torch.Size([128, 18])
# torch.Size([128])
# [4]
# torch.Size([128, 9])
# torch.Size([128])
# [5]
# torch.Size([128, 34])
# torch.Size([128])
# [6]
# torch.Size([128, 5])
# torch.Size([128])
# [7]
# torch.Size([128, 11])
# torch.Size([128])
# [8]
# torch.Size([128, 6])
# torch.Size([128])
# [9]
# torch.Size([128, 22])
# torch.Size([128])
# Epoch [10/10], Step [10/30], Loss: 0.0266, Accr: 97.63
# [10]
# torch.Size([128, 7])
# torch.Size([128])
# [11]
# torch.Size([128, 12])
# torch.Size([128])
# [12]
# torch.Size([128, 24])
# torch.Size([128])
# [13]
# torch.Size([128, 7])
# torch.Size([128])
# [14]
# torch.Size([128, 55])
# torch.Size([128])
# [15]
# torch.Size([128, 10])
# torch.Size([128])
# [16]
# torch.Size([128, 16])
# torch.Size([128])
# [17]
# torch.Size([128, 31])
# torch.Size([128])
# [18]
# torch.Size([128, 27])
# torch.Size([128])
# [19]
# torch.Size([128, 19])
# torch.Size([128])
# Epoch [10/10], Step [20/30], Loss: 0.0186, Accr: 97.96
# [20]
# torch.Size([128, 12])
# torch.Size([128])
# [21]
# torch.Size([128, 4])
# torch.Size([128])
# [22]
# torch.Size([128, 21])
# torch.Size([128])
# [23]
# torch.Size([128, 8])
# torch.Size([128])
# [24]
# torch.Size([128, 15])
# torch.Size([128])
# [25]
# torch.Size([128, 8])
# torch.Size([128])
# [26]
# torch.Size([128, 9])
# torch.Size([128])
# [27]
# torch.Size([128, 5])
# torch.Size([128])
# [28]
# torch.Size([10, 60])
# torch.Size([10])
# [29]
# torch.Size([128, 28])
# torch.Size([128])
# Epoch [10/10], Step [30/30], Loss: 0.0177, Accr: 97.74

# %% [markdown]
# ## 7. 테스트

# %%
print("Accuracy of Valid Data: %.2f" %ComputeAccr(loaders.valid_loader, model))
# Out:
# Accuracy of Valid Data: 97.74

# %% [markdown]
# ## 8. 학습된 파라미터 저장

# %%
netname = './nets/rnn_weight.pkl'
torch.save(model, netname,)
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages/torch/serialization.py:360: UserWarning: Couldn't retrieve source code for container of type RNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# ## 9. 학습된 파라미터 로드
# 실무에서 학습된 파림터 로드하고 싶다면

# %%
netname = './nets/rnn_weight.pkl'
model = torch.load(netname)

# %%
print("Accuracy of Valid Data: %.2f" %ComputeAccr(loaders.valid_loader, model))
# Out:
# Accuracy of Valid Data: 97.74
